# %%
import timm
from pprint import pprint

# %%
model_names = timm.list_models('*hrnet*', pretrained=True)
model_names
# Out:
# ['hrnet_w18.ms_aug_in1k',
#  'hrnet_w18.ms_in1k',
#  'hrnet_w18_small.gluon_in1k',
#  'hrnet_w18_small.ms_in1k',
#  'hrnet_w18_small_v2.gluon_in1k',
#  'hrnet_w18_small_v2.ms_in1k',
#  'hrnet_w18_ssld.paddle_in1k',
#  'hrnet_w30.ms_in1k',
#  'hrnet_w32.ms_in1k',
#  'hrnet_w40.ms_in1k',
#  'hrnet_w44.ms_in1k',
#  'hrnet_w48.ms_in1k',
#  'hrnet_w48_ssld.paddle_in1k',
#  'hrnet_w64.ms_in1k']

# %%
# Out:
# ['hrnet_w18.ms_aug_in1k',
#  'hrnet_w18.ms_in1k',
#  'hrnet_w18_small.gluon_in1k',
#  'hrnet_w18_small.ms_in1k',
#  'hrnet_w18_small_v2.gluon_in1k',
#  'hrnet_w18_small_v2.ms_in1k',
#  'hrnet_w18_ssld.paddle_in1k',
#  'hrnet_w30.ms_in1k',
#  'hrnet_w32.ms_in1k',
#  'hrnet_w40.ms_in1k',
#  'hrnet_w44.ms_in1k',
#  'hrnet_w48.ms_in1k',
#  'hrnet_w48_ssld.paddle_in1k',
#  'hrnet_w64.ms_in1k']
